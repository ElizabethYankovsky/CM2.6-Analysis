# %%
# %reset
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.ticker as mticker
import warnings; warnings.filterwarnings('ignore')
import cmocean
from gsw import alpha, SA_from_SP, p_from_z, CT_from_pt, beta, sigma1
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ### For CM2.6 data:

# %%
# %cd /net2/smg/documents/OMDT/analysis_CM2p6/grids
os = xr.open_dataset('ocean.static.nc')
fs = xr.open_dataset('ocean_grid.nc')
depth=fs['ht'][:,:]

lon=fs['geolon_t']; lat=fs['geolat_t']
# Coriolis is 2Omega sin(phi) where phi is the latitude of the B-grid velocity point, which should be available in hgrid
Coriolis = 2*7.29e-5*np.sin(fs['geolat_c']/360 *2*np.pi);
#dx = fs['dxt']; dy = fs['dyt']; dxy= (dx**2+dy**2)**0.5
#print(fs,os)

# %cd /archive/Richard.Slater/CM2.6/CM2.6_A_Control-1860_V03/history
#%ls
u_full = xr.open_mfdataset(['02010101.ocean_minibling_field_u.nc','02020101.ocean_minibling_field_u.nc'])['u']
v_full = xr.open_mfdataset(['02010101.ocean_minibling_field_v.nc','02020101.ocean_minibling_field_v.nc'])['v']
temp_full = xr.open_mfdataset(['02010101.ocean_minibling_field_temp.nc','02020101.ocean_minibling_field_temp.nc'])['temp']
salt_full = xr.open_mfdataset(['02010101.ocean_minibling_field_salt.nc','02020101.ocean_minibling_field_salt.nc'])['salt']
z = u_full.st_ocean
z_edges  = xr.open_dataset('02020101.ocean_minibling_field_u.nc')['st_edges_ocean']
thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u_full.st_ocean})

print(thickness)
# Out:
# /arch2/rds/CM2.6/CM2.6_A_Control-1860_V03/history
# done 1
# <xarray.DataArray 'st_edges_ocean' (st_ocean: 50)>
# array([ 10.06709957,  10.09290028,  10.12890053,  10.17849922,
#         10.24740219,  10.34269714,  10.47480392,  10.6576004 ,
#         10.9101944 ,  11.25960541,  11.74169922,  12.40619659,
#         13.32000732,  14.57260132,  16.28289795,  18.604599  ,
#         21.73239136,  25.90260315,  31.3868103 ,  38.4697876 ,
#         47.40710449,  58.35928345,  71.30871582,  85.9883728 ,
#        101.85479736, 118.14520264, 134.01159668, 148.69128418,
#        161.64074707, 172.59289551, 181.53027344, 188.61315918,
#        194.09741211, 198.26745605, 201.39550781, 203.71704102,
#        205.42749023, 206.67993164, 207.59399414, 208.25805664,
#        208.74047852, 209.08984375, 209.34228516, 209.52539062,
#        209.65722656, 209.75244141, 209.82177734, 209.87109375,
#        209.90673828, 209.93310547])
# Coordinates:
# ...

# %% [markdown]
# ### For CM2.5 data:

# %%
# %cd /work/eay/CM2.6/CM2.5_data
fs = xr.open_dataset('02010101.ocean_grid.nc')
depth=fs['ht'][:,:]

lon=fs['geolon_t']; lat=fs['geolat_t']
u_full = xr.open_mfdataset(['02010101.ocean_bgc_physics_field_u.nc','02020101.ocean_bgc_physics_field_u.nc'])['u']
v_full = xr.open_mfdataset(['02010101.ocean_bgc_physics_field_v.nc','02020101.ocean_bgc_physics_field_v.nc'])['v']
temp_full = xr.open_mfdataset(['02010101.ocean_bgc_physics_field_temp.nc','02020101.ocean_bgc_physics_field_temp.nc'])['temp']
salt_full = xr.open_mfdataset(['02010101.ocean_bgc_physics_field_salt.nc','02020101.ocean_bgc_physics_field_salt.nc'])['salt']
z = u_full.st_ocean
z_edges  = xr.open_dataset('02010101.ocean_bgc_physics_field_u.nc')['st_edges_ocean']
thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u_full.st_ocean})

# print(thickness)
# Out:
# /work2/eay/CM2.6/CM2.5_data

# %% [markdown]
# ### For CM2-1deg data:

# %%
# %cd /work/eay/CM2.6/CM2_1deg_data
fs = xr.open_dataset('01990101.ocean_grid.nc')
depth=fs['ht'][:,:]

lon=fs['geolon_t']; lat=fs['geolat_t']
u_full = xr.open_mfdataset(['01990101.ocean_bgc_physics_field_u.nc','02000101.ocean_bgc_physics_field_u.nc'])['u']
v_full = xr.open_mfdataset(['01990101.ocean_bgc_physics_field_v.nc','02000101.ocean_bgc_physics_field_v.nc'])['v']
temp_full = xr.open_mfdataset(['01990101.ocean_bgc_physics_field_temp.nc','02000101.ocean_bgc_physics_field_temp.nc'])['temp']
salt_full = xr.open_mfdataset(['01990101.ocean_bgc_physics_field_salt.nc','02000101.ocean_bgc_physics_field_salt.nc'])['salt']
z = u_full.st_ocean
z_edges  = xr.open_dataset('01990101.ocean_bgc_physics_field_u.nc')['st_edges_ocean']
thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u_full.st_ocean})

# print(thickness)
# Out:
# /work2/eay/CM2.6/CM2_1deg_data

# %% [raw]
# Argentine Basin:    [42.98S, 317.5E],    dates: [03/2015 - 04/2016]
# Southern Ocean:     [54.47S, 270.75E],   dates [01/2016 - 12/2018]
# Station PAPA:       [50.04N, 215.52E],   dates [08/2015 - 07/2016]
# Irminger Sea:       [59.98N, 320.52E],   dates [10/2014 - 01/2019]

# %% [markdown]
# Converted to our convention:

# %% [raw]
# Argentine Basin:    y=-42.98, x=-42.5     CM2.6 [767,2374]   CM2.5[297,949]   CM2-1deg[38, 237]
# Southern Ocean:     y=-54.47, x=-89.25    CM2.6 [592,1907]   CM2.5[227,762]   CM2-1deg[27, 190]
# Station PAPA:       y=50.04,  x=-144.48   CM2.6 [1824,1354]  CM2.5[719,542]   CM2-1deg[159,135]
# Irminger Sea:       y=59.98,  x=-39.48    CM2.6 [1998,2405]  CM2.5[789,961]   CM2-1deg[169,240]

# %%
#-280+(317.5-80)

# %%
a = u_full.sel(yu_ocean=-42.98,xu_ocean=-42.5,method='nearest')
print(a)
# Out:
# <xarray.DataArray 'u' (time: 146, st_ocean: 50)>
# dask.array<getitem, shape=(146, 50), dtype=float32, chunksize=(73, 50), chunktype=numpy.ndarray>
# Coordinates:
#     geolat_c  float32 dask.array<chunksize=(), meta=np.ndarray>
#     geolon_c  float32 dask.array<chunksize=(), meta=np.ndarray>
#     yu_ocean  float64 -43.0
#   * st_ocean  (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
#     xu_ocean  float64 -42.0
#   * time      (time) object 0199-01-03 12:00:00 ... 0200-12-28 12:00:00
# Attributes:
#     long_name:      i-current
#     units:          m/sec
#     valid_range:    [-10.  10.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_water_x_velocity

# %%
ilon = list(u_full.xu_ocean.values).index(u_full.sel(xu_ocean=-42.5, method='nearest').xu_ocean)
ilat = list(u_full.yu_ocean.values).index(u_full.sel(yu_ocean=-42.98, method='nearest').yu_ocean)
print(' xu_ocean=',ilon,'\n','yu_ocean=', ilat)
# Out:
#  xu_ocean= 237
#  yu_ocean= 38

# %%
print(lat[169,240].values,lon[169,240].values)
# Out:
# 59.5 -39.5

# %%
fig=depth.plot(figsize=(12, 7),cmap=cmocean.cm.matter_r)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
#plt.colorbar.set_ylabel('Depth (m)')
plt.plot(lon[767,2374],lat[767,2374],'*b',Markersize=20)
plt.plot(lon[592,1907],lat[592,1907],'*b',Markersize=20)
plt.plot(lon[1824,1354],lat[1824,1354],'*b',Markersize=20)
plt.plot(lon[1998,2405],lat[1998,2405],'*b',Markersize=20)
plt.show()

# %%
fig=depth.plot(figsize=(12, 7),cmap=cmocean.cm.matter_r)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
#plt.colorbar.set_ylabel('Depth (m)')
plt.plot(lon[297,949],lat[297,949],'*b',Markersize=20)
plt.plot(lon[227,762],lat[227,762],'*b',Markersize=20)
plt.plot(lon[719,542],lat[719,542],'*b',Markersize=20)
plt.plot(lon[789,961],lat[789,961],'*b',Markersize=20)
plt.show()

# %%
fig=depth.plot(figsize=(12, 7),cmap=cmocean.cm.matter_r)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
#plt.colorbar.set_ylabel('Depth (m)')
plt.plot(lon[38, 237],lat[38, 237],'*b',Markersize=20)
plt.plot(lon[27, 190],lat[27, 190],'*b',Markersize=20)
plt.plot(lon[159,135],lat[159,135],'*b',Markersize=20)
plt.plot(lon[169,240],lat[169,240],'*b',Markersize=20)
plt.show()

# %%
# %%time
# fig = plt.figure(figsize=(12, 7), dpi= 600, facecolor='w', edgecolor='k')
# ax = plt.subplot(projection=ccrs.Robinson(central_longitude=-140))


# plot1=plt.contourf(lon.values,lat.values,depth.values,transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter_r);
# plt.plot(lon[767,2374],lat[767,2374],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[592,1907],lat[592,1907],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[1824,1354],lat[1824,1354],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[1998,2405],lat[1998,2405],transform=ccrs.PlateCarree(),'*b',Markersize=20)

# cbar=plt.colorbar(fraction=0.046, pad=0.04,format='%.3f'); cbar.ax.tick_params(labelsize=14);
# cbar.ax.set_title('[m]', fontsize=14)

# gl=ax.gridlines(crs=ccrs.PlateCarree())
# plt.title('Bathymetry CM2.6',fontsize=18) #positive into ocean

# %% [markdown]
# ## Saving data

# %% [raw]
# Argentine Basin:    CM2.6 [767,2374]   CM2.5[297,949]   CM2-1deg[38, 237]
# Southern Ocean:     CM2.6 [592,1907]   CM2.5[227,762]   CM2-1deg[27, 190]
# Station PAPA:       CM2.6 [1824,1354]  CM2.5[719,542]   CM2-1deg[159,135]
# Irminger Sea:       CM2.6 [1998,2405]  CM2.5[789,961]   CM2-1deg[169,240]

# %%
u    = u_full[:,:,789,961]
v    = v_full[:,:,789,961]
temp = temp_full[:,:,789,961]  
salt = salt_full[:,:,789,961]
print('done')
# Out:
# done

# %%
u.geolat_c
# Out:
# <xarray.DataArray 'geolat_c' ()>
# dask.array<getitem, shape=(), dtype=float32, chunksize=(), chunktype=numpy.ndarray>
# Coordinates:
#     geolat_c  float32 dask.array<chunksize=(), meta=np.ndarray>
#     geolon_c  float32 dask.array<chunksize=(), meta=np.ndarray>
#     yu_ocean  float64 60.02
#     xu_ocean  float64 -39.5
# Attributes:
#     long_name:     uv latitude
#     units:         degrees_N
#     valid_range:   [-91.  91.]
#     cell_methods:  time: point

# %%
# %cd /work/eay/CM2.6
ds = xr.Dataset({'v': v})
print('done')
ds.to_netcdf('IrmingerSea_v.nc', 'w')
# Out:
# /work2/eay/CM2.6
# done
