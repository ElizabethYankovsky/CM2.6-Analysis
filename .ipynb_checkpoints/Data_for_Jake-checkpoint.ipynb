# %%
# %reset
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.ticker as mticker
import warnings; warnings.filterwarnings('ignore')
import cmocean
from gsw import alpha, SA_from_SP, p_from_z, CT_from_pt, beta, sigma1
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %cd /net2/smg/documents/OMDT/analysis_CM2p6/grids
os = xr.open_dataset('ocean.static.nc')
fs = xr.open_dataset('ocean_grid.nc')
depth=fs['ht'][:,:]

lon=fs['geolon_t']; lat=fs['geolat_t']
# Coriolis is 2Omega sin(phi) where phi is the latitude of the B-grid velocity point, which should be available in hgrid
Coriolis = 2*7.29e-5*np.sin(fs['geolat_c']/360 *2*np.pi);
#dx = fs['dxt']; dy = fs['dyt']; dxy= (dx**2+dy**2)**0.5
#print(fs,os)
# Out:
# /net2/smg/documents/OMDT/analysis_CM2p6/grids

# %% [markdown]
# ### For CM2.6 data:

# %%
# %cd /archive/Richard.Slater/CM2.6/CM2.6_A_Control-1860_V03/history
#%ls
u_full = xr.open_mfdataset(['02010101.ocean_minibling_field_u.nc','02020101.ocean_minibling_field_u.nc'])['u']
v_full = xr.open_mfdataset(['02010101.ocean_minibling_field_v.nc','02020101.ocean_minibling_field_v.nc'])['v']
print('done 1')
temp_full = xr.open_mfdataset(['02010101.ocean_minibling_field_temp.nc','02020101.ocean_minibling_field_temp.nc'])['temp']
salt_full = xr.open_mfdataset(['02010101.ocean_minibling_field_salt.nc','02020101.ocean_minibling_field_salt.nc'])['salt']
z = u_full.st_ocean
z_edges  = xr.open_dataset('02020101.ocean_minibling_field_u.nc')['st_edges_ocean']
thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u_full.st_ocean})

print(thickness)
# Out:
# /arch2/rds/CM2.6/CM2.6_A_Control-1860_V03/history
# done 1
# <xarray.DataArray 'st_edges_ocean' (st_ocean: 50)>
# array([ 10.06709957,  10.09290028,  10.12890053,  10.17849922,
#         10.24740219,  10.34269714,  10.47480392,  10.6576004 ,
#         10.9101944 ,  11.25960541,  11.74169922,  12.40619659,
#         13.32000732,  14.57260132,  16.28289795,  18.604599  ,
#         21.73239136,  25.90260315,  31.3868103 ,  38.4697876 ,
#         47.40710449,  58.35928345,  71.30871582,  85.9883728 ,
#        101.85479736, 118.14520264, 134.01159668, 148.69128418,
#        161.64074707, 172.59289551, 181.53027344, 188.61315918,
#        194.09741211, 198.26745605, 201.39550781, 203.71704102,
#        205.42749023, 206.67993164, 207.59399414, 208.25805664,
#        208.74047852, 209.08984375, 209.34228516, 209.52539062,
#        209.65722656, 209.75244141, 209.82177734, 209.87109375,
#        209.90673828, 209.93310547])
# Coordinates:
#   * st_ocean  (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03

# %%
print(z)
# Out:
# <xarray.DataArray 'st_ocean' (st_ocean: 50)>
# array([5.033550e+00, 1.510065e+01, 2.521935e+01, 3.535845e+01, 4.557635e+01,
#        5.585325e+01, 6.626175e+01, 7.680285e+01, 8.757695e+01, 9.862325e+01,
#        1.100962e+02, 1.221067e+02, 1.349086e+02, 1.487466e+02, 1.640538e+02,
#        1.813125e+02, 2.012630e+02, 2.247773e+02, 2.530681e+02, 2.875508e+02,
#        3.300078e+02, 3.823651e+02, 4.467263e+02, 5.249824e+02, 6.187031e+02,
#        7.286921e+02, 8.549935e+02, 9.967153e+02, 1.152376e+03, 1.319997e+03,
#        1.497562e+03, 1.683057e+03, 1.874788e+03, 2.071252e+03, 2.271323e+03,
#        2.474043e+03, 2.678757e+03, 2.884898e+03, 3.092117e+03, 3.300086e+03,
#        3.508633e+03, 3.717567e+03, 3.926813e+03, 4.136251e+03, 4.345864e+03,
#        4.555566e+03, 4.765369e+03, 4.975209e+03, 5.185111e+03, 5.395023e+03])
# Coordinates:
#   * st_ocean  (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
# Attributes:
#     long_name:       tcell zstar depth
#     units:           meters
#     cartesian_axis:  Z
#     positive:        down
#     edges:           st_edges_ocean

# %% [markdown]
# ### For CM2.5 data:

# %%
# %cd /work/eay/CM2.6/CM2.5data_02020101
# diag_BCKE= xr.open_dataset('02020101.ocean_energy_vort.nc')['kinetic_energy_clinic_intz'][6] #for one month
# diag_BTKE= xr.open_dataset('02020101.ocean_energy_vort.nc')['kinetic_energy_tropic'][6]      #for one month

# u = xr.open_dataset('02020101.ocean_bgc_physics_field_u.nc')['u']
# v = xr.open_dataset('02020101.ocean_bgc_physics_field_v.nc')['v']
# z = u.st_ocean
# z_edges  = xr.open_dataset('02020101.ocean_bgc_physics_field_u.nc')['st_edges_ocean']
# thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u.st_ocean})

# # print(thickness)

# %% [markdown]
# ### For CM2-1deg data:

# %%
# %cd /work/eay/CM2.6/CM2_1degdata_02000101
# diag_BCKE= xr.open_dataset('02000101.ocean_energy_vort.nc')['kinetic_energy_clinic_intz'][6]
# diag_BTKE= xr.open_dataset('02000101.ocean_energy_vort.nc')['kinetic_energy_tropic'][6]

# u = xr.open_dataset('02000101.ocean_bgc_physics_field_u.nc')['u']
# v = xr.open_dataset('02000101.ocean_bgc_physics_field_v.nc')['v']
# z = u.st_ocean
# z_edges  = xr.open_dataset('02000101.ocean_bgc_physics_field_u.nc')['st_edges_ocean']
# thickness= z_edges.diff('st_edges_ocean').rename({'st_edges_ocean': 'st_ocean'}).assign_coords({"st_ocean":u.st_ocean})

# print(thickness)

# %% [raw]
# Argentine Basin:    [42.98S, 317.5E],    dates: [03/2015 - 04/2016]
# Southern Ocean:     [54.47S, 270.75E],   dates [01/2016 - 12/2018]
# Station PAPA:       [50.04N, 215.52E],   dates [08/2015 - 07/2016]
# Irminger Sea:       [59.98N, 320.52E],   dates [10/2014 - 01/2019]

# %% [markdown]
# Converted to our convention:

# %% [raw]
# Argentine Basin:    y=-42.98, x=-42.5     CM2.6 [767,2374]
# Southern Ocean:     y=-54.47, x=-89.25    CM2.6 [592,1907]
# Station PAPA:       y=50.04,  x=-144.48   CM2.6 [1824,1354]
# Irminger Sea:       y=59.98,  x=-39.48    CM2.6 [1998,2405]

# %%
#-280+(317.5-80)

# %%
a = u_full.sel(yu_ocean=59.98,xu_ocean=-39.48,method='nearest')
print(a)
# Out:
# <xarray.DataArray 'u' (time: 73, st_ocean: 50)>
# array([[-0.022339, -0.031888, -0.035512, ...,       nan,       nan,       nan],
#        [ 0.086977,  0.047916,  0.02828 , ...,       nan,       nan,       nan],
#        [ 0.024626, -0.006922, -0.019246, ...,       nan,       nan,       nan],
#        ...,
#        [-0.066567, -0.076846, -0.080699, ...,       nan,       nan,       nan],
#        [-0.078007, -0.099566, -0.108825, ...,       nan,       nan,       nan],
#        [-0.124403, -0.109008, -0.100651, ...,       nan,       nan,       nan]],
#       dtype=float32)
# Coordinates:
#     xu_ocean  float64 -39.5
#     yu_ocean  float64 59.97
#   * st_ocean  (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
#   * time      (time) object 0202-01-03 12:00:00 ... 0202-12-29 12:00:00
# Attributes:
#     long_name:      i-current
#     units:          m/sec
#     valid_range:    [-10.  10.]
#     cell_methods:   time: mean
#     time_avg_info:  average_T1,average_T2,average_DT
#     coordinates:    geolon_c geolat_c
#     standard_name:  sea_water_x_velocity

# %%
ilon = list(u_full.xu_ocean.values).index(u_full.sel(xu_ocean=-39.48, method='nearest').xu_ocean)
ilat = list(u_full.yu_ocean.values).index(u_full.sel(yu_ocean=59.98, method='nearest').yu_ocean)
print(' xu_ocean=',ilon,'\n','yu_ocean=', ilat)
# Out:
#  xu_ocean= 2404
#  yu_ocean= 1998

# %%
print(lat[1998,2405].values,lon[1998,2405].values)
# Out:
# 59.9468994140625 -39.45

# %%
fig=depth.plot(figsize=(12, 7),cmap=cmocean.cm.matter_r)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
#plt.colorbar.set_ylabel('Depth (m)')
plt.plot(lon[767,2374],lat[767,2374],'*b',Markersize=20)
plt.plot(lon[592,1907],lat[592,1907],'*b',Markersize=20)
plt.plot(lon[1824,1354],lat[1824,1354],'*b',Markersize=20)
plt.plot(lon[1998,2405],lat[1998,2405],'*b',Markersize=20)
plt.show()

# %%
# %%time
# fig = plt.figure(figsize=(12, 7), dpi= 600, facecolor='w', edgecolor='k')
# ax = plt.subplot(projection=ccrs.Robinson(central_longitude=-140))


# plot1=plt.contourf(lon.values,lat.values,depth.values,transform=ccrs.PlateCarree(),cmap=cmocean.cm.matter_r);
# plt.plot(lon[767,2374],lat[767,2374],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[592,1907],lat[592,1907],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[1824,1354],lat[1824,1354],transform=ccrs.PlateCarree(),'*b',Markersize=20)
# plt.plot(lon[1998,2405],lat[1998,2405],transform=ccrs.PlateCarree(),'*b',Markersize=20)

# cbar=plt.colorbar(fraction=0.046, pad=0.04,format='%.3f'); cbar.ax.tick_params(labelsize=14);
# cbar.ax.set_title('[m]', fontsize=14)

# gl=ax.gridlines(crs=ccrs.PlateCarree())
# plt.title('Bathymetry CM2.6',fontsize=18) #positive into ocean

# %% [markdown]
# ## Saving data

# %% [raw]
# Argentine Basin:    CM2.6 [767,2374]
# Southern Ocean:     CM2.6 [592,1907]
# Station PAPA:       CM2.6 [1824,1354]
# Irminger Sea:       CM2.6 [1998,2405]

# %%
u    = u_full[:,:,1998,2405]
v    = v_full[:,:,1998,2405]
temp = temp_full[:,:,1998,2405]  
salt = salt_full[:,:,1998,2405]
print('done')
# Out:
# done

# %%
# %cd /work/eay/CM2.6
ds = xr.Dataset({'u': u,'v': v,'temp':temp,'salt':salt})
print('done')
ds.to_netcdf('IrmingerSea.nc', 'w')
# Out:
# /work2/eay/CM2.6
# done

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:   (st_ocean: 50, time: 146)
# Coordinates:
#     yu_ocean  float64 59.97
#     xu_ocean  float64 -39.4
#   * st_ocean  (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
#   * time      (time) object 0201-01-03 12:00:00 ... 0202-12-29 12:00:00
#     yt_ocean  float64 59.95
#     xt_ocean  float64 -39.45
# Data variables:
#     u         (time, st_ocean) float32 dask.array<chunksize=(73, 50), meta=np.ndarray>
#     v         (time, st_ocean) float32 dask.array<chunksize=(73, 50), meta=np.ndarray>
#     temp      (time, st_ocean) float32 dask.array<chunksize=(73, 50), meta=np.ndarray>
#     salt      (time, st_ocean) float32 dask.array<chunksize=(73, 50), meta=np.ndarray>
