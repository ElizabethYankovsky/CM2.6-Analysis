# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import mixture
from sklearn.decomposition import PCA
from sklearn import preprocessing
import netCDF4 as nc
import glob
import pandas as pd
import xarray as xr

# %%
# base path
base = '/scratch/ab10313/Spectral_Database/new_from_hector/Spectral_Database_vII/'
winter_KE = 'winter/KE/'
summer_KE = 'summer/KE/'
filename = 'Spectrum_00888_at_LON_-41.0_LAT_55.386.nc'

# load data
data_path = glob.glob(base+winter_KE+'*.nc')
#ds_winter_KE = nc.MFDataset(data_path)
#data_path


file_path = base+summer_KE+filename
ds = nc.Dataset(file_path)

# %%
# base path
base = '/scratch/ab10313/Spectral_Database/new_from_hector/Spectral_Database_vII/'
winter_KE = 'winter/KE/'
summer_KE = 'summer/KE/'

# load data
data_path = glob.glob(base+summer_KE+'*.nc')

pca = PCA(.75)
prepoc_spectra_flat = np.zeros((len(data_path),540*101))

for i_file in range(len(data_path)):
    
    file_path = data_path[i_file]
    ds = nc.Dataset(file_path)

    wvnum = ds['Wvnumber'][:]
    freq = ds['Frequency'][:]
    spectra = ds['Spectrum'][:]
    freq_mat = np.tile(freq, ( wvnum.size,1))
    wvnum_mat = np.transpose(np.tile(wvnum,(freq.size,1)))

    # Preprocessing
 #   prepoc_spectra = preprocessing.normalize(np.transpose(spectra*wvnum_mat*freq_mat))
    prepoc_spectra_flat[i_file,:] = preprocessing.normalize(np.transpose(spectra*wvnum_mat*freq_mat)).flatten()
    
# PCA on spectra
#lower_dimensional_data = pca.fit_transform(prepoc_spectra_flat)
#approximation = pca.inverse_transform(lower_dimensional_data)
    
#winter_KE_spectra_PCA[i_file,:] =

# %%
prepoc_spectra_flat.shape

# %%
prepoc_spectra_flat.shape

# PCA on spectra
lower_dimensional_data = pca.fit_transform(prepoc_spectra_flat)
lower_dimensional_data.shape
#approximation = pca.inverse_transform(lower_dimensional_data)
# Out:
# (888, 13)

# %%
from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=4, random_state=0).fit(lower_dimensional_data)
#gm.means_

#gm.predict([[0, 0], [12, 3]])

       
#gmm = GMM(n_components=4).fit(lower_dimensional_data)
#labels = gmm.predict(lower_dimensional_data)

# %%
labels = gm.predict(lower_dimensional_data)
labels.shape
# Out:
# (888,)

# %%
wvnum = ds['Wvnumber'][:]
freq = ds['Frequency'][:]
    
spectra = ds['Spectrum'][:]
freq_mat = np.tile(freq, ( wvnum.size,1))
wvnum_mat = np.transpose(np.tile(wvnum,(freq.size,1)))

# %%
# Preprocessing
prepoc_spectra = preprocessing.normalize(np.transpose(spectra*wvnum_mat*freq_mat))
prepoc_spectra_flat = preprocessing.normalize(np.transpose(spectra*wvnum_mat*freq_mat)).flatten()

# %%
prepoc_spectra_flat.reshape(len(freq),len(wvnum)).shape
prepoc_spectra.shape
# Out:
# (540, 101)

# %%
plt.pcolor(  wvnum,freq, prepoc_spectra_flat.reshape(len(freq),len(wvnum)),cmap='inferno')
plt.loglog()
plt.axis([5e-3, 2.5e-1,1e-3, 2.5e-1])
plt.colorbar()

# %%
plt.plot(freq, np.mean(prepoc_spectra,axis=1))
plt.loglog()
#plt.axis([5e-3, 2.5e-1,1e-2, 1e2])
# Out:
# []

# %% [markdown]
# # PCA for dimensionality reduction

# %%
spectra_pca = prepoc_spectra_flat
plt.pcolor(  wvnum,freq, spectra_pca.reshape(len(freq),len(wvnum)),cmap='inferno', vmin=0, vmax =1)
plt.loglog()
plt.axis([5e-3, 2.5e-1,1e-3, 2.5e-1])
plt.colorbar()

# %%
pca = PCA(.95)
lower_dimensional_data = pca.fit_transform(spectra_pca)
approximation = pca.inverse_transform(lower_dimensional_data)
lower_dimensional_data.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /state/partition1/job-16599704/ipykernel_3864655/1361582311.py in <module>
#       1 pca = PCA(.9)
# ----> 2 lower_dimensional_data = pca.fit_transform(spectra_pca)
#       3 approximation = pca.inverse_transform(lower_dimensional_data)
#       4 lower_dimensional_data.shape
#
# /ext3/miniconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     405         C-ordered array, use 'np.ascontiguousarray'.
#     406         """
# --> 407         U, S, Vt = self._fit(X)
#     408         U = U[:, : self.n_components_]
#     409
#
# /ext3/miniconda3/lib/python3.9/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     428             )
#     429
# --> 430         X = self._validate_data(
#     431             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
# ...

# %%
plt.plot(lower_dimensional_data[0,:])
plt.plot(lower_dimensional_data[1,:])
plt.plot(lower_dimensional_data[100,:])

# %%
plt.pcolor(  wvnum,freq, approximation,cmap='inferno',vmin=0, vmax =1)
plt.loglog()
plt.axis([6e-3, 2.5e-1,1e-3, 2.5e-1])
plt.colorbar()

# %%
plt.plot(freq, np.mean(approximation,axis=1))
plt.plot(freq, np.mean(prepoc_spectra,axis=1))
plt.loglog()
#plt.axis([6e-3, 2.5e-1,1e-2, 1e2])
# Out:
# []

# %% [markdown]
# # Make Dataset for GMM
#
# Here we make a dataset from the global spectra.
# To start, we wwill no use PCA just to see the results.
#
# ## Wednesday
# 1. Make dataset for GMM
# 2. Try to apply GMM to cluster
# 3. Think about using multiple variables (SSH, KE, SST), and summer and winter for each?
# 4. Reach out to Torres about plotting to get code to generate map.
# 5. Rethink the PCA part.
